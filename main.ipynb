# %% [markdown]
# <a href="https://colab.research.google.com/github/flowarko/ObjectDetection/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Download source files
# !git clone https://github.com/flowarko/ObjectDetection.git
# !cp -r ObjectDetection/src ./ 
# !mkdir img
# !rm -rf ObjectDetection
# Out:
# Cloning into 'ObjectDetection'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 29 (delta 8), reused 20 (delta 6), pack-reused 0
# Unpacking objects: 100% (29/29), done.

# %%
# Imports
import tensorflow_hub as hub
import numpy as np 
import os
import matplotlib.pyplot as plt

from src.object_detection import ObjectDetection

# %%
def showImage(image):
    fig = plt.figure(figsize=(20, 15))
    plt.grid(False)
    plt.imshow(image)

# %%
#@title Only use this if you saved the model local on your machine
model = ""
detector = hub.load(model).signatures['default']

# %%
model = "https://tfhub.dev/google/openimages_v4/ssd/mobilenet_v2/1"
detector = hub.load(model).signatures['default']
# Out:
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore

# %%
od = ObjectDetection(detector)

# %%
testimage = "file:" + os.path.join(os.getcwd(), "img", "testimage.jpg")

# %%
tmp_img = od.downloadResize(testimage, 1280, 856)
output = od.runDetector(tmp_img)
# Out:
# [od]	Image temporarily downloaded to /tmp/tmp3jc0cpkt.jpg

# %%
showImage(output)
